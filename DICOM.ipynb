# %%
# !pip install pydicom pandas matplotlib openslide-python openslide-bin
# Out:
# Requirement already satisfied: pydicom in c:\users\daniel\documents\personal\breast_cancer_detection\.venv\lib\site-packages (3.0.1)
# Requirement already satisfied: pandas in c:\users\daniel\documents\personal\breast_cancer_detection\.venv\lib\site-packages (2.3.3)
# Requirement already satisfied: matplotlib in c:\users\daniel\documents\personal\breast_cancer_detection\.venv\lib\site-packages (3.10.7)
# Collecting openslide-python
#   Downloading openslide_python-1.4.2-cp311-abi3-win_amd64.whl.metadata (5.0 kB)
# Collecting openslide-bin
#   Downloading openslide_bin-4.0.0.8-py3-none-win_amd64.whl.metadata (4.5 kB)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\daniel\documents\personal\breast_cancer_detection\.venv\lib\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\daniel\documents\personal\breast_cancer_detection\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\daniel\documents\personal\breast_cancer_detection\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\daniel\documents\personal\breast_cancer_detection\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\daniel\documents\personal\breast_cancer_detection\.venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\daniel\documents\personal\breast_cancer_detection\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\daniel\documents\personal\breast_cancer_detection\.venv\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\daniel\documents\personal\breast_cancer_detection\.venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\daniel\documents\personal\breast_cancer_detection\.venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\daniel\documents\personal\breast_cancer_detection\.venv\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\daniel\documents\personal\breast_cancer_detection\.venv\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\daniel\documents\personal\breast_cancer_detection\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading openslide_python-1.4.2-cp311-abi3-win_amd64.whl (35 kB)
# Downloading openslide_bin-4.0.0.8-py3-none-win_amd64.whl (4.2 MB)
#    ---------------------------------------- 0.0/4.2 MB ? eta -:--:--
#    -- ------------------------------------- 0.2/4.2 MB 6.4 MB/s eta 0:00:01
#    ------ --------------------------------- 0.7/4.2 MB 9.2 MB/s eta 0:00:01
#    ------------------- -------------------- 2.0/4.2 MB 14.0 MB/s eta 0:00:01
#    ------------------------------------ --- 3.8/4.2 MB 20.1 MB/s eta 0:00:01
#    ---------------------------------------- 4.2/4.2 MB 20.5 MB/s eta 0:00:00
# Installing collected packages: openslide-python, openslide-bin
# Successfully installed openslide-bin-4.0.0.8 openslide-python-1.4.2
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pydicom
import pandas as pd
import matplotlib.pyplot as plt

# %%
dicom_df = None
file_path = f'D:\\tfm\\data\\CBIS-DDSM\\Calc-Test_P_00038_LEFT_CC\\1.3.6.1.4.1.9590.100.1.2.85935434310203356712688695661986996009\\1.3.6.1.4.1.9590.100.1.2.374115997511889073021386151921807063992\\1-1.dcm'

# Load the DICOM file
dicom_data = pydicom.dcmread(file_path)
dicom_data.decode()
dicom_df = pd.DataFrame(dicom_data.values())
dicom_df[0] = dicom_df[0].apply(lambda x: pydicom.dataelem.DataElement_from_raw(x) if isinstance(x, pydicom.dataelem.RawDataElement) else x)
dicom_df['name'] = dicom_df[0].apply(lambda x: x.name)
dicom_df['value'] = dicom_df[0].apply(lambda x: x.value)
dicom_df = dicom_df[['name', 'value']]

dicom_df = dicom_df.set_index('name').T.reset_index(drop=True)
print(dicom_df.columns.tolist())
dicom_df
    
    # Access the pixel data
    # image = dicom_data.pixel_array
    
    # plt.imshow(image, cmap="gray")
    # plt.title("DICOM Image")
    # plt.axis("off")
    # plt.show()
# Out:
# ['Specific Character Set', 'SOP Class UID', 'SOP Instance UID', 'Study Date', 'Content Date', 'Study Time', 'Content Time', 'Accession Number', 'Modality', 'Conversion Type', "Referring Physician's Name", "Patient's Name", 'Patient ID', "Patient's Birth Date", "Patient's Sex", 'Body Part Examined', 'Secondary Capture Device Manufacturer', "Secondary Capture Device Manufacturer's Model Name", 'Study Instance UID', 'Series Instance UID', 'Study ID', 'Series Number', 'Instance Number', 'Patient Orientation', 'Samples per Pixel', 'Photometric Interpretation', 'Rows', 'Columns', 'Bits Allocated', 'Bits Stored', 'High Bit', 'Pixel Representation', 'Smallest Image Pixel Value', 'Largest Image Pixel Value', 'Pixel Data']
# name Specific Character Set              SOP Class UID  \
# 0                ISO_IR 100  1.2.840.10008.5.1.4.1.1.7
#
# name                                   SOP Instance UID Study Date  \
# 0     1.3.6.1.4.1.9590.100.1.2.289923739312470966435...
#
# name Content Date Study Time   Content Time Accession Number Modality  \
# 0        20160503             105946.779000                        MG
#
# name Conversion Type  ... Photometric Interpretation  Rows Columns  \
# 0                WSD  ...                MONOCHROME2  4616    3016
#
# name Bits Allocated Bits Stored High Bit Pixel Representation  \
# 0                16          16       15                    0
#
# name Smallest Image Pixel Value Largest Image Pixel Value  \
# 0                             0                     61780
#
# name                                         Pixel Data
# 0     b'l\x96*\x96\x82\x96\x95\x93\x0c\x95\xca\x94\x...
#
# [1 rows x 35 columns]

# %%
import openslide

# Replace this with the path to your .svs file
svs_path = "D:/TFM/breast_cancer_detection/data/PKG - CPTAC-BRCA_v1/BRCA/01BR001-4ffefc66-d0ba-4a36-b4fa-35bd91.svs"

# Open the slide
slide = openslide.OpenSlide(svs_path)

# Read a region of the slide at level 0 (highest resolution)
region = slide.read_region(location=(0, 0), level=0, size=(200, 200))

# Display it using matplotlib
plt.imshow(region)
plt.title("SVS Slide Preview (Top-Left Corner)")
plt.axis("off")
plt.show()
